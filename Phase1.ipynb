# %% [markdown]
# <a href="https://colab.research.google.com/github/lama-a1/IT326-Project-Fitness/blob/main/Phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "id": "c71b163f",
   "metadata": {},
   "source": [
    "# Phase1: Dataset Overview\n",
    "\n",
    "This notebook documents the dataset and basic exploratory facts required for *Phase 1*.\n"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "0dae68d6",
   "metadata": {},
   "source": [
    "## 1) Project Goal\n",
    "\n",
    "**Goal (classification + clustering):** Predict whether a person is *fit* or *not fit* from measurable lifestyle and health attributes (age, height, weight, heart rate, blood pressure, sleep, nutrition quality, activity, smoking, gender); optionally, explore **clustering** to group people with similar wellness profiles.\n"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "933e109a",
   "metadata": {},
   "source": [
    "## 2) Dataset Source\n",
    "\n",
    "Add the exact source and link you used (example placeholder below).\n",
    "\n",
    "- **Source:** Kaggle — *<add dataset name here>*  \n",
    "- **URL:** *<paste link here>*\n"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "6bddf214",
   "metadata": {},
   "source": [
    "## 3) Load the Dataset\n",
    "\n",
    "> **In Colab:** Choose one of the two options below.\n",
    "\n",
    "### Option A — Upload the CSV\n",
    "Run the next cell and upload your CSV when prompted.\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": None,
   "id": "fa38204d",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Option A: manual upload\n",
    "from google.colab import files\n",
    "import io, pandas as pd\n",
    "\n",
    "uploaded = files.upload()  # choose your CSV file\n",
    "csv_name = next(iter(uploaded.keys()))\n",
    "df = pd.read_csv(io.BytesIO(uploaded[csv_name]))\n",
    "print('Loaded:', csv_name, df.shape)\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "45c395cf",
   "metadata": {},
   "source": [
    "### Option B — Load from Google Drive\n",
    "If your CSV is in Drive, mount it and point to the file path.\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": None,
   "id": "d0d27f0b",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Option B: Google Drive\n",
    "from google.colab import drive\n",
    "import pandas as pd\n",
    "drive.mount('/content/drive')\n",
    "csv_path = '/content/drive/MyDrive/path/to/fitness_dataset.csv'  # <-- change me\n",
    "df = pd.read_csv(csv_path)\n",
    "print('Loaded:', csv_path, df.shape)\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "12732cc9",
   "metadata": {},
   "source": [
    "## 4) Dataset Description\n",
    "\n",
    "The following cells print the **number and data types of attributes**, **number of objects**, **class attribute and counts**, and a **sample of the raw dataset**.\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": None,
   "id": "ab7744f0",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Basic facts\n",
    "import pandas as pd\n",
    "import numpy as np\n",
    "\n",
    "# Replace with your class column if different\n",
    "CLASS_COL = 'is_fit'\n",
    "\n",
    "n_rows, n_cols = df.shape\n",
    "print(f'# Objects (instances): {n_rows}')\n",
    "print(f'# Attributes (columns): {n_cols}')\n",
    "\n",
    "print('\\nData types:')\n",
    "display(pd.DataFrame({'attribute': df.columns, 'dtype': df.dtypes.astype(str).values}))\n",
    "\n",
    "print('\\nClass attribute:', CLASS_COL)\n",
    "if CLASS_COL in df.columns:\n",
    "    counts = df[CLASS_COL].value_counts(dropna=False).sort_index()\n",
    "    display(counts.to_frame('count').T)\n",
    "else:\n",
    "    print('WARNING: class column not found—set CLASS_COL above.')\n",
    "\n",
    "print('\\nSample of raw dataset:')\n",
    "display(df.head(10))"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "0eb2ff7d",
   "metadata": {},
   "source": [
    "### Notes / Assumptions\n",
    "- `is_fit` is treated as the **class label** (binary: 0 = not fit, 1 = fit). If your dataset uses a different label column, change `CLASS_COL` accordingly.\n",
    "- No cleaning or modeling is performed in this notebook; it only reports required descriptive facts.\n"
   ]
  }
 ],
 "metadata": {},
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# {'cells': [{'cell_type': 'markdown',
#    'id': 'c71b163f',
#    'metadata': {},
#    'source': ['# Phase1: Dataset Overview\n',
#     '\n',
#     'This notebook documents the dataset and basic exploratory facts required for *Phase 1*.\n']},
#   {'cell_type': 'markdown',
#    'id': '0dae68d6',
#    'metadata': {},
#    'source': ['## 1) Project Goal\n',
#     '\n',
#     '**Goal (classification + clustering):** Predict whether a person is *fit* or *not fit* from measurable lifestyle and health attributes (age, height, weight, heart rate, blood pressure, sleep, nutrition quality, activity, smoking, gender); optionally, explore **clustering** to group people with similar wellness profiles.\n']},
#   {'cell_type': 'markdown',
#    'id': '933e109a',
#    'metadata': {},
#    'source': ['## 2) Dataset Source\n',
#     '\n',
#     'Add the exact source and link you used (example placeholder below).\n',
#     '\n',
#     '- **Source:** Kaggle — *<add dataset name here>*  \n',
# ...
